# %% [markdown]
# # Weather Analysis - ARSO data

# %% [markdown]
# Data was collected from the website: http://meteo.arso.gov.si/met/sl/archive/

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', index_col=0, parse_dates=True, dayfirst=True)
weather_data['2014-01-01 00:00:00':'2014-01-31 00:00:00'][['T', 'globalno sev. [W/m2]',
                                                               'hitrost vetra [m/s]','kolicina padavin [mm]']].describe()
# Out:
#                  T  globalno sev. [W/m2]  hitrost vetra [m/s]  \
# count  1435.000000           1441.000000          1431.000000
# mean      5.352857             31.959750             1.087631
# std       3.778312             67.544294             0.819923
# min      -2.800000              0.000000             0.000000
# 25%       2.750000              0.000000             0.500000
# 50%       6.600000              0.000000             0.900000
# 75%       8.100000             31.000000             1.400000
# max      12.800000            442.000000             5.100000
#
#        kolicina padavin [mm]
# count            1441.000000
# mean                0.109785
# std                 0.388830
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 4.800000

# %% [markdown]
# ## Ploting Some Measurements

# %% [markdown]
# Plotting Temperature, Radiation, Wind speed and Rainfall for January 2014.

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', index_col=0, parse_dates=True, dayfirst=True)
_ = weather_data['2014-01-01 00:00:00':'2014-01-31 00:00:00'][['T', 'globalno sev. [W/m2]',
                                                               'hitrost vetra [m/s]','kolicina padavin [mm]']].plot(
    x_compat=True, subplots=True, style=['r','g','b','r'], layout=(2,2),figsize=(20,7))

# %% [markdown]
# ## Calculate Average Temp and Deviation

# %% [markdown]
# From the historical data (from 1994 to 2014), we calculate average Temperature for January. Bellow we can see average temperature for one day (1. Jan 2014), with standard deviatons. Mean standard deviation for January is 4.2 C.

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', index_col=0, parse_dates=True, dayfirst=True)

average = weather_data.groupby([ weather_data.index.day, weather_data.index.time])['T'].mean()

weather_data = weather_data.join(pd.DataFrame(average).rename(columns={"T":"AvrT"}), 
                                           on=[weather_data.index.day, weather_data.index.time], how = 'left')

std = weather_data.groupby([ weather_data.index.day, weather_data.index.time])['T'].std()
print "Mean standard deviation: ", std.mean()

weather_data = weather_data.join(pd.DataFrame(std).rename(columns={"T":"StdT"}), 
                                           on=[weather_data.index.day, weather_data.index.time], how = 'left')

weather_data
_ = weather_data['2014-01-01 00:00:00':'2014-01-01 23:30:00'][['AvrT','StdT']].plot(kind='bar', figsize=(18,4), 
                                                                                 title="Average Temperature", yerr='StdT')
# Out:
# Mean standard deviation:  4.22238661007

# %% [markdown]
# ## Compare Average Temp to Temp from 2014

# %% [markdown]
# Comparing January average temperature with temperature from 2014.

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', index_col=0, parse_dates=True, dayfirst=True)

average = weather_data.groupby([ weather_data.index.day, weather_data.index.time])['T'].mean()

weather_data = weather_data.join(pd.DataFrame(average).rename(columns={"T":"AvrT"}), 
                                           on=[weather_data.index.day, weather_data.index.time], how = 'left')

_ = weather_data['2014-01-01 00:00:00':'2014-01-31 23:30:00'][['AvrT','T']].plot(x_compat=True, figsize=(18,4), 
                                                                                 title="Average Temperature")

# %% [markdown]
# ## Compare Average Temp to Other Years Temp

# %% [markdown]
# Comparing January average temperature, with all other January temperatures from 1994 to 2014.

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', index_col=0, parse_dates=True, dayfirst=True)

average = weather_data.groupby([ weather_data.index.day, weather_data.index.time])['T'].mean()

weather_data = weather_data.join(pd.DataFrame(average).rename(columns={"T":"AvrT"}), 
                                           on=[weather_data.index.day, weather_data.index.time], how = 'left')

plt.figure(figsize=(20,6))
grouped = weather_data.groupby(weather_data.index.year)
for i, group in weather_data.groupby(weather_data.index.year):
    ax = group['T'].plot(use_index=False, legend=True, label=i)
    
weather_data[0:group.shape[0]]['AvrT'].plot(use_index=False, linewidth=3.0)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# ## Comapring Average Temperatures with Standard Deviatons.

# %% [markdown]
# Same as previous, only with standard deviation.

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', index_col=0, parse_dates=True, dayfirst=True)

mean = weather_data.groupby([ weather_data.index.day, weather_data.index.time])['T'].mean()
std = weather_data.groupby([ weather_data.index.day, weather_data.index.time])['T'].std()

weather_data = weather_data.join(pd.DataFrame(mean).rename(columns={"T":"AvrT"}), 
                                           on=[weather_data.index.day, weather_data.index.time], how = 'left')

weather_data = weather_data.join(pd.DataFrame(std).rename(columns={"T":"StdT"}), 
                                           on=[weather_data.index.day, weather_data.index.time], how = 'left')

plt.figure(figsize=(20,6))

for i, group in weather_data.groupby(weather_data.index.year):
    ax = group['T'].plot(use_index=False, legend=True, label=i)

weather_data[0:group.shape[0]]['AvrT'].plot(use_index=False, linewidth=3.0)
plt.fill_between(np.arange(len(group)),
             (weather_data['AvrT'] + weather_data['StdT']/2)[0:group.shape[0]].values,
             (weather_data['AvrT'] - weather_data['StdT']/2)[0:group.shape[0]].values, 
             alpha=0.5, color='b')
#plt.plot(weather_data[0:group.shape[0]].index,
#         weather_data['AvrT'][0:group.shape[0]], linewidth=3.0)

plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# ## Temperature Heatmap

# %% [markdown]
# Visualizing January temperatures over years from 1994 to 2014. It is clear, how some year like 2014 were hotter than usually, whicle some years like 2009 were colder.

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', parse_dates=[0], dayfirst=True)

weather_data["DayTime"] = weather_data['datetime'].apply(lambda x: x.strftime('%b-%dT%H:%M:%S'))
weather_data["Year"] = weather_data['datetime'].apply(lambda x: x.year)
#weather_data.pivot(weather_data['DayTime'], weather_data['Year'], 'T')

temperature = pd.DataFrame.pivot_table(weather_data, index=['DayTime'], columns=['Year'], values='T')
#temperature["Average"] = temperature.apply(np.mean, axis=1)
diff = temperature.sub(temperature.apply(np.mean, axis=1), axis=0)


# Format tick
xticks = diff.index
keptticks = xticks[::int(len(xticks)/10)]
xticks = ['' for y in xticks]
xticks[::int(len(xticks)/10)] = keptticks

# Display heatmap
#plt.figure(figsize=(10,7))
sns.heatmap(temperature.T, linewidths=0, cmap="RdBu_r" ,xticklabels=xticks) # Plot temperature heatmap
#sns.heatmap(diff.T, linewidths=0, cmap="RdBu_r" ,xticklabels=xticks) # Plot temperature difference heatmap

# %% [markdown]
# ## Difference from Average Temperature Heatmap

# %% [markdown]
# Similar plot as above, butvisualizing differences between temperature and average temperature. Since average temperature is

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', parse_dates=[0], dayfirst=True)

weather_data["DayTime"] = weather_data['datetime'].apply(lambda x: x.strftime('%b-%dT%H:%M:%S'))
weather_data["Year"] = weather_data['datetime'].apply(lambda x: x.year)
#weather_data.pivot(weather_data['DayTime'], weather_data['Year'], 'T')

temperature = pd.DataFrame.pivot_table(weather_data, index=['DayTime'], columns=['Year'], values='T')
#temperature["Average"] = temperature.apply(np.mean, axis=1)
diff = temperature.sub(temperature.apply(np.mean, axis=1), axis=0)


# Format tick
xticks = diff.index
keptticks = xticks[::int(len(xticks)/10)]
xticks = ['' for y in xticks]
xticks[::int(len(xticks)/10)] = keptticks

# Display heatmap
#plt.figure(figsize=(10,7))
#sns.heatmap(temperature.T, linewidths=0, cmap="RdBu_r" ,xticklabels=xticks) # Plot temperature heatmap
sns.heatmap(diff.T, linewidths=0, cmap="RdBu_r" ,xticklabels=xticks) # Plot temperature difference heatmap

# %% [markdown]
# ## Barplot

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', parse_dates=[0], dayfirst=True)

weather_data["DayTime"] = weather_data['datetime'].apply(lambda x: pd.to_datetime(x.strftime('%b-%dT%H:%M:%S'), format="%b-%dT%H:%M:%S"))
weather_data["Year"] = weather_data['datetime'].apply(lambda x: x.year)
#weather_data.pivot(weather_data['DayTime'], weather_data['Year'], 'T')

temperature = pd.DataFrame.pivot_table(weather_data, index=['DayTime'], columns=['Year'], values='T')

plt.figure(figsize=(15,6))
plt.xticks(rotation=45)
sns.boxplot(temperature.loc[:, range(1994,2015)])
plt.ylabel("January Temperature")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
weather_data = pd.read_csv(".\data\weather_jan.csv", encoding='cp1250', parse_dates=[0], dayfirst=True)

weather_data["DayTime"] = weather_data['datetime'].apply(lambda x: pd.to_datetime(x.strftime('%b-%dT%H:%M:%S'), format="%b-%dT%H:%M:%S"))
weather_data["Year"] = weather_data['datetime'].apply(lambda x: x.year)
#weather_data.pivot(weather_data['DayTime'], weather_data['Year'], 'T')

temperature = pd.DataFrame.pivot_table(weather_data, index=['DayTime'], columns=['Year'], values='T')
plot_vals = [v.dropna() for k, v in temperature.iteritems()] 

plt.figure(figsize=(15,7))
plt.xticks(rotation=45)
sns.violinplot(plot_vals, names=temperature.columns)
plt.ylabel("January Temperature")
plt.show
# Out:
# <function matplotlib.pyplot.show>
